# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import json

# %%
with open('./data/ebay_ev_sales_data.json') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'price': 'US $48,900.00\nBest offer accepted  ',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $48,900.00\nBest offer accepted  ',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $42,000.00',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $46,900.00',
#   'Condition': 'Used',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ... Read more\nabout the seller notes',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $50,500.00\nBest offer accepted  ',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $63,188.00',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2020',
#   'VIN (Vehicle Identification Number)': '5YJXCBE22LF271739',
#   'Mileage': '37500',
#   'Interior Color': 'White',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/295670955949?hash=item44d75cbfad:g:DgYAAOSw2wRkUEV9&amdata=enc%3AAQAIAAAAwNx%2FwtvEvJMZFvvtT1QyVb7IjI%2Ff2fJYICAM738vMgSlOcJpRSls27vorRnvXmuczSSPph69MBDjvCSSbNRQOWYBCqH47lvLMira8ABuf1oIr8SXGBwV85erpmX5x5Ptm0LqTClu94m%2FscOAbZO2yx8eR14H3z9CVpn2daQw2AUkx1ZgQZ4BUydZVQCcnhfoqbb1n9DaZ8Zkgsv1yZWK7VesgVHMyl699YtD4dcWEonSDBMnvpTxdd%2BEuqFNfHfVYQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $47,000.00',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE23KF209291',
#   'Mileage': '40566',
#   'Interior Color': 'Black',
#   'Sub Model': 'AWD',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Trim': 'Long Range',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Private Seller',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'Electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows, Power Locks, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/166070077984?hash=item26aa8c4a20:g:pKYAAOSwbOJkUa8M&amdata=enc%3AAQAIAAAA4MoQ%2FP02tUVCShc8vIH0hqmGr6U6QbsdIDz%2FAHfqT6m%2B9ler0o9YBaJuCCYBxzylORwP%2BtA5xHRJo2bxvyk5LffOmmRX7%2Fmh1yEjIK82DnKrJQWb026xk1ZgJw3Ar4A25EQLWpbPUl4U8ClPqQKHTyDuk0E%2F7Rj%2F%2FyeM%2FBLqYAKEIXxMXH5DIZwIcLpreXB9dDwyo6ZrNNSqfnDkxbKxHZJ2jRyQ9cURgbzc%2BpkrTA2gBnSbEUF7Vqk0kJlRd8oW%2BupTmhFhPS%2F1tzm5fJUjc%2FcXjUIVJpCgvG%2BCvxjt%2Bupc%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $43,995.00\nBest offer accepted  ',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCBE25GF004844',
#   'Mileage': '70446',
#   'Interior Color': 'White',
#   'Options': 'Sunroof, Leather Seats',
#   'Sub Model': 'X 90D',
#   'Body Type': 'SUV',
#   'Warranty': 'Unspecified',
#   'Trim': '90D',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Locks, Power Windows, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/314556514971?hash=item493d07829b:g:D3YAAOSwwHBkSsAv&amdata=enc%3AAQAIAAAAwLpTySslINKXZ9as1gnMvD0ahRlWfQpfjrWvsINWC7Mvh%2BYr69CegvQlBB%2FgwWNc9LHgpgCoqogid%2FJLSEXriVAU1XliK4r9deg5kyeppZR9gGOv3Qo%2BDSq1sFEUDStoqtd6pHjiNC1sE57it%2FlIXhNiovp3PbdgC2QHS5hGGZAwd5pfsLr7jmwEQitkR0wYl39m%2BAQ1NmjtfxrMEMiluViVsz1uCZE0qnJL8qc%2F1OztBEg%2Bf8RUL2%2Fu4Zbr1Ct02w%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': 'US $58,000.00\nBest offer accepted  ',
#   'Condition': 'Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ... Read more\nabout the condition',
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCBE26KF182836',
#   'Mileage': '23285',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'White',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/385579292179?hash=item59c6511613:g:FeQAAOSwVyNkTFe6&amdata=enc%3AAQAIAAAAwD%2Bzeo7RE7h6tYbq%2BDUfR0DxOlF3jcWZmZR8PtjV9%2FSjWoi1%2Ffo6qXcwofwdMAID7LkMhGe4U6ndKvZ9GtmEIpzhPMQUnnonFR%2BK34bKwasUIRtswVgfPAhBB3KWtMCxhlBlOm0nDvwVG1t2S1u8MYsDEfSjDyVpPhulX2gFuLbapFfQe96YN6d3FEbgKlXuhyI8%2F6B2sO%2FydvrJFdSB6g%2FS8LpjSNB9Na7Arhjj4SdpRE5pEFThWJuvAJtiARBAdQ%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $46,900.00|',
#   'Condition': 'Used',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ...  Read moreabout the seller notes“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades Package, comes with 20in and 22in rims as seen on pictures, 2 sets of keys, Towing package. Warranty on motors and battery until 12/15/2025 unlimited miles. Asking $46,900 or best offer, vehicle is located in Miami FL” Read Lessabout the seller notes ',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $63,188.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2020',
#   'VIN (Vehicle Identification Number)': '5YJXCBE22LF271739',
#   'Mileage': '37500',
#   'Interior Color': 'White',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/295670955949?hash=item44d75cbfad:g:DgYAAOSw2wRkUEV9&amdata=enc%3AAQAIAAAAwNx%2FwtvEvJMZFvvtT1QyVb7IjI%2Ff2fJYICAM738vMgSlOcJpRSls27vorRnvXmuczSSPph69MBDjvCSSbNRQOWYBCqH47lvLMira8ABuf1oIr8SXGBwV85erpmX5x5Ptm0LqTClu94m%2FscOAbZO2yx8eR14H3z9CVpn2daQw2AUkx1ZgQZ4BUydZVQCcnhfoqbb1n9DaZ8Zkgsv1yZWK7VesgVHMyl699YtD4dcWEonSDBMnvpTxdd%2BEuqFNfHfVYQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $47,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE23KF209291',
#   'Mileage': '40566',
#   'Interior Color': 'Black',
#   'Sub Model': 'AWD',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Trim': 'Long Range',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Private Seller',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'Electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows, Power Locks, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/166070077984?hash=item26aa8c4a20:g:pKYAAOSwbOJkUa8M&amdata=enc%3AAQAIAAAA4MoQ%2FP02tUVCShc8vIH0hqmGr6U6QbsdIDz%2FAHfqT6m%2B9ler0o9YBaJuCCYBxzylORwP%2BtA5xHRJo2bxvyk5LffOmmRX7%2Fmh1yEjIK82DnKrJQWb026xk1ZgJw3Ar4A25EQLWpbPUl4U8ClPqQKHTyDuk0E%2F7Rj%2F%2FyeM%2FBLqYAKEIXxMXH5DIZwIcLpreXB9dDwyo6ZrNNSqfnDkxbKxHZJ2jRyQ9cURgbzc%2BpkrTA2gBnSbEUF7Vqk0kJlRd8oW%2BupTmhFhPS%2F1tzm5fJUjc%2FcXjUIVJpCgvG%2BCvxjt%2Bupc%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $43,995.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCBE25GF004844',
#   'Mileage': '70446',
#   'Interior Color': 'White',
#   'Options': 'Sunroof, Leather Seats',
#   'Sub Model': 'X 90D',
#   'Body Type': 'SUV',
#   'Warranty': 'Unspecified',
#   'Trim': '90D',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Locks, Power Windows, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/314556514971?hash=item493d07829b:g:D3YAAOSwwHBkSsAv&amdata=enc%3AAQAIAAAAwLpTySslINKXZ9as1gnMvD0ahRlWfQpfjrWvsINWC7Mvh%2BYr69CegvQlBB%2FgwWNc9LHgpgCoqogid%2FJLSEXriVAU1XliK4r9deg5kyeppZR9gGOv3Qo%2BDSq1sFEUDStoqtd6pHjiNC1sE57it%2FlIXhNiovp3PbdgC2QHS5hGGZAwd5pfsLr7jmwEQitkR0wYl39m%2BAQ1NmjtfxrMEMiluViVsz1uCZE0qnJL8qc%2F1OztBEg%2Bf8RUL2%2Fu4Zbr1Ct02w%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': '|US $58,000.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCBE26KF182836',
#   'Mileage': '23285',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'White',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/385579292179?hash=item59c6511613:g:FeQAAOSwVyNkTFe6&amdata=enc%3AAQAIAAAAwD%2Bzeo7RE7h6tYbq%2BDUfR0DxOlF3jcWZmZR8PtjV9%2FSjWoi1%2Ffo6qXcwofwdMAID7LkMhGe4U6ndKvZ9GtmEIpzhPMQUnnonFR%2BK34bKwasUIRtswVgfPAhBB3KWtMCxhlBlOm0nDvwVG1t2S1u8MYsDEfSjDyVpPhulX2gFuLbapFfQe96YN6d3FEbgKlXuhyI8%2F6B2sO%2FydvrJFdSB6g%2FS8LpjSNB9Na7Arhjj4SdpRE5pEFThWJuvAJtiARBAdQ%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $46,900.00|',
#   'Condition': 'Used',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ...  Read moreabout the seller notes“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades Package, comes with 20in and 22in rims as seen on pictures, 2 sets of keys, Towing package. Warranty on motors and battery until 12/15/2025 unlimited miles. Asking $46,900 or best offer, vehicle is located in Miami FL” Read Lessabout the seller notes ',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': 'US $63,188.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2020',
#   'VIN (Vehicle Identification Number)': '5YJXCBE22LF271739',
#   'Mileage': '37500',
#   'Interior Color': 'White',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/295670955949?hash=item44d75cbfad:g:DgYAAOSw2wRkUEV9&amdata=enc%3AAQAIAAAAwNx%2FwtvEvJMZFvvtT1QyVb7IjI%2Ff2fJYICAM738vMgSlOcJpRSls27vorRnvXmuczSSPph69MBDjvCSSbNRQOWYBCqH47lvLMira8ABuf1oIr8SXGBwV85erpmX5x5Ptm0LqTClu94m%2FscOAbZO2yx8eR14H3z9CVpn2daQw2AUkx1ZgQZ4BUydZVQCcnhfoqbb1n9DaZ8Zkgsv1yZWK7VesgVHMyl699YtD4dcWEonSDBMnvpTxdd%2BEuqFNfHfVYQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $47,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE23KF209291',
#   'Mileage': '40566',
#   'Interior Color': 'Black',
#   'Sub Model': 'AWD',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Trim': 'Long Range',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Private Seller',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'Electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows, Power Locks, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/166070077984?hash=item26aa8c4a20:g:pKYAAOSwbOJkUa8M&amdata=enc%3AAQAIAAAA4MoQ%2FP02tUVCShc8vIH0hqmGr6U6QbsdIDz%2FAHfqT6m%2B9ler0o9YBaJuCCYBxzylORwP%2BtA5xHRJo2bxvyk5LffOmmRX7%2Fmh1yEjIK82DnKrJQWb026xk1ZgJw3Ar4A25EQLWpbPUl4U8ClPqQKHTyDuk0E%2F7Rj%2F%2FyeM%2FBLqYAKEIXxMXH5DIZwIcLpreXB9dDwyo6ZrNNSqfnDkxbKxHZJ2jRyQ9cURgbzc%2BpkrTA2gBnSbEUF7Vqk0kJlRd8oW%2BupTmhFhPS%2F1tzm5fJUjc%2FcXjUIVJpCgvG%2BCvxjt%2Bupc%7Ctkp%3ABk9SR4KS4eGIYg'},
#  {'price': '|US $43,995.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCBE25GF004844',
#   'Mileage': '70446',
#   'Interior Color': 'White',
#   'Options': 'Sunroof, Leather Seats',
#   'Sub Model': 'X 90D',
#   'Body Type': 'SUV',
#   'Warranty': 'Unspecified',
#   'Trim': '90D',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Locks, Power Windows, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/314556514971?hash=item493d07829b:g:D3YAAOSwwHBkSsAv&amdata=enc%3AAQAIAAAAwLpTySslINKXZ9as1gnMvD0ahRlWfQpfjrWvsINWC7Mvh%2BYr69CegvQlBB%2FgwWNc9LHgpgCoqogid%2FJLSEXriVAU1XliK4r9deg5kyeppZR9gGOv3Qo%2BDSq1sFEUDStoqtd6pHjiNC1sE57it%2FlIXhNiovp3PbdgC2QHS5hGGZAwd5pfsLr7jmwEQitkR0wYl39m%2BAQ1NmjtfxrMEMiluViVsz1uCZE0qnJL8qc%2F1OztBEg%2Bf8RUL2%2Fu4Zbr1Ct02w%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': '|US $58,000.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCBE26KF182836',
#   'Mileage': '23285',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'White',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/385579292179?hash=item59c6511613:g:FeQAAOSwVyNkTFe6&amdata=enc%3AAQAIAAAAwD%2Bzeo7RE7h6tYbq%2BDUfR0DxOlF3jcWZmZR8PtjV9%2FSjWoi1%2Ffo6qXcwofwdMAID7LkMhGe4U6ndKvZ9GtmEIpzhPMQUnnonFR%2BK34bKwasUIRtswVgfPAhBB3KWtMCxhlBlOm0nDvwVG1t2S1u8MYsDEfSjDyVpPhulX2gFuLbapFfQe96YN6d3FEbgKlXuhyI8%2F6B2sO%2FydvrJFdSB6g%2FS8LpjSNB9Na7Arhjj4SdpRE5pEFThWJuvAJtiARBAdQ%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256048040264'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '155552048142'},
#  {'price': '|US $46,900.00|',
#   'Condition': 'Used',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ...  Read moreabout the seller notes“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades Package, comes with 20in and 22in rims as seen on pictures, 2 sets of keys, Towing package. Warranty on motors and battery until 12/15/2025 unlimited miles. Asking $46,900 or best offer, vehicle is located in Miami FL” Read Lessabout the seller notes ',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '225550054810'},
#  {'price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256066075946'},
#  {'price': 'US $63,188.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2020',
#   'VIN (Vehicle Identification Number)': '5YJXCBE22LF271739',
#   'Mileage': '37500',
#   'Interior Color': 'White',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/295670955949?hash=item44d75cbfad:g:DgYAAOSw2wRkUEV9&amdata=enc%3AAQAIAAAAwNx%2FwtvEvJMZFvvtT1QyVb7IjI%2Ff2fJYICAM738vMgSlOcJpRSls27vorRnvXmuczSSPph69MBDjvCSSbNRQOWYBCqH47lvLMira8ABuf1oIr8SXGBwV85erpmX5x5Ptm0LqTClu94m%2FscOAbZO2yx8eR14H3z9CVpn2daQw2AUkx1ZgQZ4BUydZVQCcnhfoqbb1n9DaZ8Zkgsv1yZWK7VesgVHMyl699YtD4dcWEonSDBMnvpTxdd%2BEuqFNfHfVYQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '295670955949'},
#  {'price': '|US $43,995.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCBE25GF004844',
#   'Mileage': '70446',
#   'Interior Color': 'White',
#   'Options': 'Sunroof, Leather Seats',
#   'Sub Model': 'X 90D',
#   'Body Type': 'SUV',
#   'Warranty': 'Unspecified',
#   'Trim': '90D',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Locks, Power Windows, Power Seats',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'item_link': 'https://www.ebay.com/itm/314556514971?hash=item493d07829b:g:D3YAAOSwwHBkSsAv&amdata=enc%3AAQAIAAAAwLpTySslINKXZ9as1gnMvD0ahRlWfQpfjrWvsINWC7Mvh%2BYr69CegvQlBB%2FgwWNc9LHgpgCoqogid%2FJLSEXriVAU1XliK4r9deg5kyeppZR9gGOv3Qo%2BDSq1sFEUDStoqtd6pHjiNC1sE57it%2FlIXhNiovp3PbdgC2QHS5hGGZAwd5pfsLr7jmwEQitkR0wYl39m%2BAQ1NmjtfxrMEMiluViVsz1uCZE0qnJL8qc%2F1OztBEg%2Bf8RUL2%2Fu4Zbr1Ct02w%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg',
#   'item_id': '314556514971'},
#  {'price': '|US $58,000.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCBE26KF182836',
#   'Mileage': '23285',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'White',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/385579292179?hash=item59c6511613:g:FeQAAOSwVyNkTFe6&amdata=enc%3AAQAIAAAAwD%2Bzeo7RE7h6tYbq%2BDUfR0DxOlF3jcWZmZR8PtjV9%2FSjWoi1%2Ffo6qXcwofwdMAID7LkMhGe4U6ndKvZ9GtmEIpzhPMQUnnonFR%2BK34bKwasUIRtswVgfPAhBB3KWtMCxhlBlOm0nDvwVG1t2S1u8MYsDEfSjDyVpPhulX2gFuLbapFfQe96YN6d3FEbgKlXuhyI8%2F6B2sO%2FydvrJFdSB6g%2FS8LpjSNB9Na7Arhjj4SdpRE5pEFThWJuvAJtiARBAdQ%3D%3D%7Ctkp%3ABk9SR4SS4eGIYg',
#   'item_id': '385579292179'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   '|Condition:': 'Used',
#   'Ended:': '|\r|May 16, 2023|14:03:36 PDT|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256048040264'},
#  {'price': '|US $42,000.00|',
#   '|Condition:': 'Used',
#   'Ended:': '|\r|May 12, 2023|19:33:22 PDT|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '155552048142'},
#  {'price': '|US $46,900.00|',
#   '|Condition:': 'Used',
#   'Ended:': '|\r|May 09, 2023|11:21:20 PDT|',
#   'Condition': 'Used',
# ...
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '225550054810'},
#  {'price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Ended': '|\r|May 09, 2023|09:06:01 PDT|',
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256066075946'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256048040264'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '155552048142'},
#  {'price': '|US $46,900.00|',
#   'Condition': 'Used',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ...  Read moreabout the seller notes“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades Package, comes with 20in and 22in rims as seen on pictures, 2 sets of keys, Towing package. Warranty on motors and battery until 12/15/2025 unlimited miles. Asking $46,900 or best offer, vehicle is located in Miami FL” Read Lessabout the seller notes ',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '225550054810'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256048040264'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '155552048142'},
#  {'price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': 'Used',
#   'Ended': '|\r|May 16, 2023|14:03:36 PDT|',
#   'Price': '|US $48,900.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Located in': 'Memphis, Tennessee, United States',
#   'Seller Notes': '“2018 Tesla Model X 100D 295 FULL CHARGE Ready for new owner.”',
#   'Year': '2018',
#   'VIN (Vehicle Identification Number)': '5YJXCAE25JF089783',
#   'Mileage': '78398',
#   'Interior Color': 'Black',
#   'Sub Model': 'Model X 100D 295 FULL CHARGE',
#   'Body Type': 'SUV',
#   'Warranty': 'Vehicle has an existing warranty',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'Safety Features': 'Anti-Lock Brakes, Driver Airbag, Passenger Airbag, Side Airbags',
#   'For Sale By': 'Dealer',
#   'Drive Side': 'Left-hand drive',
#   'Fuel': 'electric',
#   'Model': 'Model X',
#   'Exterior Color': 'Gray',
#   'Disability Equipped': 'No',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/256048040264?hash=item3b9da70948:g:fHIAAOSwieBkPtU~&amdata=enc%3AAQAIAAAAwMYpbKTPPpChZHBE9RJjvHvE%2B%2BxiqM7FG0BDDo0B502BPtXd1VpmOIjdlLj3wxzDc%2Fc%2Bm36IDbLHZAL4uxZXcIjHRoTmvK0QdYIILdy2AhV1CvRYpsdZg0%2FXnc2XZrwuw4J7YpWbHJiny14CAnLuEJPnuvvGZV6Hbh7ZJo5WucloyV0Hp3vQUGXNjxK129a9S%2FawYgT5%2Br0SR81vzzrrEVmXQDD60H4HqzPbhyenwROg9C5hIh3ThQtf01qzjbOvBQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256048040264'},
#  {'price': '|US $42,000.00|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Ended': '|\r|May 12, 2023|19:33:22 PDT|',
#   'Price': '|US $42,000.00|',
#   'Located in': 'San Diego, California, United States',
#   'Year': '2016',
#   'VIN (Vehicle Identification Number)': '5YJXCAE49GF001909',
#   'Mileage': '65000',
#   'For Sale By': 'Private Seller',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'Fuel Type': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/155552048142?hash=item24379fe40e:g:c9YAAOSwdR5kXqYE&amdata=enc%3AAQAIAAAAwNb2fZ3lslOMtfgXIeDjh5JV7VzqnHHMCfuVpUi0975O9Ve68qSCICD3zTN6wvt1WM5FNR5xvxBbpCdcEgdI4QF9ehuSgcA5YWL7vfvhKnhJXqF4xy1XoZwfLiW5aCWO0RzHXp9Y7Y7zzH3MH4QqLZsC8a0lXqW4cSg6wqOppDNmHblfAkPPggXA3wWVerKUdSTC5V%2BhU8REwhnFfUJ1Vxivu8tlj7uddNqLu9IMWIjU3AttvbP%2Fag3dv%2FQiFrv6%2FQ%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '155552048142'},
#  {'price': '|US $46,900.00|',
#   'Condition': 'Used',
#   'Ended': '|\r|May 09, 2023|11:21:20 PDT|',
#   'Price': '|US $46,900.00|',
#   'Located in': 'Miami, Florida, United States',
#   'Seller Notes': '“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades ...  Read moreabout the seller notes“7 seater, white interior with Carbon Fiber Decor, Full Self Driving, MCU2, Premium Upgrades Package, comes with 20in and 22in rims as seen on pictures, 2 sets of keys, Towing package. Warranty on motors and battery until 12/15/2025 unlimited miles. Asking $46,900 or best offer, vehicle is located in Miami FL” Read Lessabout the seller notes ',
#   'Year': '2017',
#   'VIN (Vehicle Identification Number)': '5YJXCAE21HF078337',
#   'Mileage': '84713',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Make': 'Tesla',
#   'Drive Type': 'AWD',
#   'Fuel Type': 'Electric',
#   'For Sale By': 'Private Seller',
#   'Model': 'Model X',
#   'Exterior Color': 'Black',
#   'Vehicle Title': 'Clean',
#   'Engine': 'Electric',
#   'item_link': 'https://www.ebay.com/itm/225550054810?hash=item3483d4b59a:g:dVkAAOSwHWFjxjBD&amdata=enc%3AAQAIAAAAwAtS535dKIcANoWEhZbTVeT7aQgFYp3r3sqGCsT7LK0VBqThXZFp9D1zGBpskbBk3EwLjl8sbO%2FcR9V591k%2BTZmLB2FrHBR0PeqQjSn85F9QOkEx9Z2KxtykzTU8CsZq4lZoWt0%2BrSlqO17clNIpPbORJcjT%2BG26XzBNe5zjuIfpO0M7mJQgErvgYPFqKrZULOZrF1erJYagEuVCr2IWFx%2FGNsh7YgIU5iEy%2B%2BY8jjvKjtmXrbzWaKpKLx4K6qdmdA%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '225550054810'},
#  {'price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Condition': "Used: A vehicle is considered used if it has been registered and issued a title. Used vehicles have ...  Read moreabout the conditionUsed: A vehicle is considered used if it has been registered and issued a title. Used vehicles have had at least one previous owner. The condition of the exterior, interior and engine can vary depending on the vehicle's history. See the seller's listing for full details and description of any imperfections. See all condition definitionsopens in a new window or tab ",
#   'Ended': '|\r|May 09, 2023|09:06:01 PDT|',
#   'Price': '|US $50,500.00|Best offer accepted|\xa0|This item was listed in the fixed price format with a Best Offer option. The seller accepted a Best Offer price.|',
#   'Located in': 'Hollywood, Florida, United States',
#   'Year': '2019',
#   'VIN (Vehicle Identification Number)': '5YJXCAE20KF155657',
#   'Mileage': '11400',
#   'Make': 'Tesla',
#   'Model': 'Model X',
#   'Trim': '100D Sport Utility 4D',
#   'For Sale By': 'Dealer',
#   'Warranty': 'Vehicle does NOT have an existing warranty',
#   'Vehicle Title': 'Salvage',
#   'Exterior Color': 'Blue',
#   'Interior Color': 'White',
#   'Body Type': 'SUV',
#   'Transmission': 'Automatic',
#   'Doors': '4',
#   'Safety Features': 'Anti-Lock Brakes, Driver Side Airbag',
#   'Power Options': 'Air Conditioning, Cruise Control, Power Windows',
#   'Fuel Type': 'Electric',
#   'Engine Description': 'ELECTRIC MOTOR',
#   'item_link': 'https://www.ebay.com/itm/256066075946?hash=item3b9eba3d2a:g:AVAAAOSwN6xkWPzX&amdata=enc%3AAQAIAAAAwGhx%2BzIlUphAvol9E6J2Rm%2Fcz8FyCsm6O607sIiQiUPMZChTMfS52gUBZ%2FA7jEHAouw%2BXmPuZLHqfQLrfD81NOE6fQF3G9Ekj3d9ThzokYK%2BNkjcEShvuny6JEngLqf5eVkE4L9HfHt6FiRHzM%2BRar0vuzTv2yvPVImNC6bZRt6Ubt90u9m1RlnIq2SHzxApWlMIZWURnEiDTTcC2zbRNmklMj9nfhPq39YLHSb8mJyHzLAue2dM6R9frxIbrvqhKg%3D%3D%7Ctkp%3ABk9SR4KS4eGIYg',
#   'item_id': '256066075946'}]

# %%
keys = set()
for d in data:
    keys.update(set(d.keys()))

# %%
len(keys)
# Out:
# 35

# %%
keys
# Out:
# {'Body Type',
#  'Condition',
#  'Disability Equipped',
#  'Doors',
#  'Drive Side',
#  'Drive Type',
#  'Ended',
#  'Ended:',
#  'Engine',
#  'Engine Description',
#  'Exterior Color',
#  'For Sale By',
#  'Fuel',
#  'Fuel Type',
#  'Interior Color',
#  'Located in',
#  'Make',
#  'Mileage',
#  'Model',
#  'Options',
#  'Power Options',
#  'Price',
#  'Safety Features',
#  'Seller Notes',
#  'Sub Model',
#  'Transmission',
#  'Trim',
#  'VIN (Vehicle Identification Number)',
#  'Vehicle Title',
#  'Warranty',
#  'Year',
#  'item_id',
#  'item_link',
#  'price',
#  '|Condition:'}
