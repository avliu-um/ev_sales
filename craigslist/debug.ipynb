# %% [markdown]
# ## Debug Dups

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/2023_08_07_lansing_links_p3.csv')

# %%
df.groupby('url').size()
# Out:
# url
# https://akroncanton.craigslist.org/cto/d/akron-1976-oldsmobile-cutlass-supreme/7652178335.html    2
# https://akroncanton.craigslist.org/cto/d/akron-2012-ford-focus-se-135k-miles/7652179569.html      2
# https://akroncanton.craigslist.org/cto/d/berea-2010-scion-tc-speed/7652218868.html                2
# https://akroncanton.craigslist.org/cto/d/cuyahoga-falls-2004-chevy-ton-dump/7652186575.html       2
# https://akroncanton.craigslist.org/cto/d/lakemore-2012-ford-escape-limited-v6/7652169764.html     2
#                                                                                                  ..
# https://toledo.craigslist.org/ctd/d/ortonville-2015-ram-1500-sport-4x4/7652159834.html            2
# https://toledo.craigslist.org/ctd/d/ortonville-2017-ford-150-lariat-fx4-4x4/7652144613.html       2
# https://toledo.craigslist.org/ctd/d/ortonville-2020-gmc-sierra-3500hd/7652153049.html             2
# ...

# %%
## util get_soup()
def get_soup(url):

    success = False
    sleep_time = 1
    max_sleep_time = 60 * 5

    req, html_page = None, None
    while not success:
        try:
            req = Request(url)
            html_page = urlopen(req)
            success = True
        except urllib.error.HTTPError as e:
            print(f'error {e.code}')
            if 500 <= e.code <= 599 and sleep_time < max_sleep_time:
                print(f'server error; sleep {sleep_time} seconds')
                time.sleep(sleep_time)
                sleep_time *= 2
            else:
                raise e

    soup = BeautifulSoup(html_page, 'html.parser')

# %%
import requests

# %%
last_page_url = f'https://lansing.craigslist.org/search/cta?postal=48933' \
       f'&postedToday=1&search_distance=200#search=1~gallery~5~0'
last_page_url
# Out:
# 'https://lansing.craigslist.org/search/cta?postal=48933&postedToday=1&search_distance=200#search=1~gallery~5~0'

# %%
res = requests.get(last_page_url)
res.url
# Out:
# 'https://lansing.craigslist.org/search/cta?postal=48933&postedToday=1&search_distance=200#search=1~gallery~5~0'

# %%
res.status_code
# Out:
# 200

# %%
res.is_redirect
# Out:
# False

# %%
res.links.keys()
# Out:
# dict_keys([])

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.content, 'html.parser')

# %%
page_css = 'div[class="cl-search-paginator"]'
page = soup.select(page_css) 
page
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="Cars &amp; Trucks near Lansing, MI 48933 - craigslist" property="og:title"/>
# <meta content="Cars &amp; Trucks near Lansing, MI 48933 - craigslist" name="description"/>
# <meta content="Cars &amp; Trucks near Lansing, MI 48933 - craigslist" property="og:description"/>
# <meta content="https://lansing.craigslist.org/search/cta" property="og:url"/>
# <title>Cars &amp; Trucks near Lansing, MI 48933 - craigslist</title>
# <link href="https://lansing.craigslist.org/search/cta" rel="canonical"/>
# <link href="https://lansing.craigslist.org/search/cta" hreflang="x-default" rel="alternate"/>
# <script id="ld_searchpage_data" type="application/ld+json">
# ...
